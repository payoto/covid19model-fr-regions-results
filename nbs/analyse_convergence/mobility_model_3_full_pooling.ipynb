# %% [markdown]
# # Analysis of model convergence for mobility with full pooling
#
# This notebook explores the convergence of the model on a consistant prediction as more data is fed into it.
#
#
# The model explored here uses a different formula for mobility which separates all the values even those judged too colinear by the authors of the original study.
#
#  + Pooling formula: `~ -1 + residential + transit + grocery + parks + retail + workplace`
#  + Partial pooling formula: `~ -1`
#
# This criteria is defined in function `is_desired_pooling`
#
# No partial pooling here, this means a single set of parameters are used for the 14 countries and French regions.

# %% [markdown]
# All functions are defined in [`mobility_model_analyse.ipynb`](mobility_model_analyse.ipynb) it is ran here
# using the ipython magic.

# %%
# %run mobility_model_analyse.ipynb

# %% [markdown]
# Must change directory as imports and data are from the root of the project

# %% [markdown]
# ## Load Data

# %%
run_manifest = read_manifest('run-manifest.csv')
analysis_set = get_analysis_set(run_manifest)

# %% [markdown]
# ## Group data in comparable runs
#
# To group analysis runs we define `is_desired_pooling` which returns a true or false value

# %%
def is_desired_pooling(df, x):
    return (
        '~ -1 + residential + transit + grocery + parks + retail + workplace'
        == df.loc[x, "model"].data["arguments"]["formula_pooling"].strip()
    ) and (
        '~ -1'
        == df.loc[x, "model"].data["arguments"]["formula_partialpooling"].strip()
    )

groups = analysis_set.groupby(lambda x : group_region_fit_and_pooling(analysis_set, x, is_desired_pooling))

# %% [markdown]
# Check what groups have been created

# %%
for i, group in enumerate(groups):
    print(f"Group {i + 1} of {len(groups)}: {group[0]}")
# Out:
# Group 1 of 21: ('v2', 'Europe', 'No region', False, '', '')
# Group 2 of 21: ('v2', 'Europe', 'With regions', False, '', '')
# Group 3 of 21: ('v2', 'France only', 'With regions', False, '', '')
# Group 4 of 21: ('v3', 'Europe', 'With regions', False, '', '')
# Group 5 of 21: ('v3', 'France only', 'With regions', False, '', '')
# Group 6 of 21: ('v5', 'Europe', 'No region', False, '~ -1 + residential + transit + averageMobility', '~ -1 + residential + transit + averageMobility')
# Group 7 of 21: ('v5', 'Europe', 'No region', False, '~ -1 + residential + transit + grocery + parks + retail + workplace', '~ -1 + residential + transit + grocery + parks + retail + workplace')
# Group 8 of 21: ('v5', 'Europe', 'No region', False, '~ -1 + residential + transit + grocery + parks + retail + workplace', '~ -1 + transit + retail')
# Group 9 of 21: ('v5', 'Europe', 'No region', True, '~ -1 + residential + transit + grocery + parks + retail + workplace', '~ -1')
# Group 10 of 21: ('v5', 'Europe', 'With regions', False, '~ -1 + residential + transit + averageMobility', '~ -1 + residential + transit + averageMobility')
# Group 11 of 21: ('v5', 'Europe', 'With regions', False, '~ -1 + residential + transit + grocery + parks + retail + workplace', '~ -1 + residential + transit + grocery + parks + retail + workplace')
# Group 12 of 21: ('v5', 'Europe', 'With regions', False, '~ -1 + residential + transit + grocery + parks + retail + workplace', '~ -1 + transit + retail')
# Group 13 of 21: ('v5', 'Europe', 'With regions', True, '~ -1 + residential + transit + grocery + parks + retail + workplace', '~ -1')
# Group 14 of 21: ('v5', 'France only', 'No region', False, '~ -1 + residential + transit + averageMobility', '~ -1 + residential + transit + averageMobility')
# Group 15 of 21: ('v5', 'France only', 'No region', False, '~ -1 + residential + transit + grocery + parks + retail + workplace', '~ -1 + residential + transit + grocery + parks + retail + workplace')
# Group 16 of 21: ('v5', 'France only', 'No region', False, '~ -1 + residential + transit + grocery + parks + retail + workplace', '~ -1 + transit + retail')
# Group 17 of 21: ('v5', 'France only', 'No region', True, '~ -1 + residential + transit + grocery + parks + retail + workplace', '~ -1')
# Group 18 of 21: ('v5', 'France only', 'With regions', False, '~ -1 + residential + transit + averageMobility', '~ -1 + residential + transit + averageMobility')
# Group 19 of 21: ('v5', 'France only', 'With regions', False, '~ -1 + residential + transit + grocery + parks + retail + workplace', '~ -1 + residential + transit + grocery + parks + retail + workplace')
# Group 20 of 21: ('v5', 'France only', 'With regions', False, '~ -1 + residential + transit + grocery + parks + retail + workplace', '~ -1 + transit + retail')
# Group 21 of 21: ('v5', 'France only', 'With regions', True, '~ -1 + residential + transit + grocery + parks + retail + workplace', '~ -1')

# %% [markdown]
# ## Analysis of convergence on France
#
# The next few plots display data for France as a whole modelled from a range of different dates.

# %%
french_regions = ["France-hopitaux", "France-OC19"]

# %%
report_on_zones(french_regions, select_with_regions)
# Out:
# ### France-hopitaux
# Plotting group 13 of 21: ('v5', 'Europe', 'With regions', True, '~ -1 + residential + transit + grocery + parks + retail + workplace', '~ -1')
# Plotting group 21 of 21: ('v5', 'France only', 'With regions', True, '~ -1 + residential + transit + grocery + parks + retail + workplace', '~ -1')
# ### France-OC19
# Plotting group 13 of 21: ('v5', 'Europe', 'With regions', True, '~ -1 + residential + transit + grocery + parks + retail + workplace', '~ -1')
# Plotting group 21 of 21: ('v5', 'France only', 'With regions', True, '~ -1 + residential + transit + grocery + parks + retail + workplace', '~ -1')

# %% [markdown]
# ## Case study of European countries

# %%
countries = ['Spain', 'Italy', "United_Kingdom", 'Germany', 'Netherlands', 'Portugal', 'Denmark', 'Sweden']

# %%
report_on_zones(countries, select_europe_only)
# Out:
# ### Spain
# Plotting group 9 of 21: ('v5', 'Europe', 'No region', True, '~ -1 + residential + transit + grocery + parks + retail + workplace', '~ -1')
# ### Italy
# Plotting group 9 of 21: ('v5', 'Europe', 'No region', True, '~ -1 + residential + transit + grocery + parks + retail + workplace', '~ -1')
# ### United_Kingdom
# Plotting group 9 of 21: ('v5', 'Europe', 'No region', True, '~ -1 + residential + transit + grocery + parks + retail + workplace', '~ -1')
# ### Germany
# Plotting group 9 of 21: ('v5', 'Europe', 'No region', True, '~ -1 + residential + transit + grocery + parks + retail + workplace', '~ -1')
# ### Netherlands
# Plotting group 9 of 21: ('v5', 'Europe', 'No region', True, '~ -1 + residential + transit + grocery + parks + retail + workplace', '~ -1')
# ### Portugal
# Plotting group 9 of 21: ('v5', 'Europe', 'No region', True, '~ -1 + residential + transit + grocery + parks + retail + workplace', '~ -1')
# ### Denmark
# Plotting group 9 of 21: ('v5', 'Europe', 'No region', True, '~ -1 + residential + transit + grocery + parks + retail + workplace', '~ -1')
# ### Sweden
# Plotting group 9 of 21: ('v5', 'Europe', 'No region', True, '~ -1 + residential + transit + grocery + parks + retail + workplace', '~ -1')

# %% [markdown]
# ## Conclusions

# %% [markdown]
# ### Note on convergence

# %% [markdown]
# ### Future works

# %% [markdown]
# ## Acknowledgements / Thanks
#
# - The MRC at Imperial for open sourcing the model and their support
# - [Nathan Desdouits](https://github.com/nathan-tc) for his advice on cleaning up the colours of the plots.
