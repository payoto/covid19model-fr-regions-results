# %% [markdown]
# # Analysis of model convergence for mobility configuration of report 20
#
# This notebook explores the convergence of the model on a consistant prediction as more data is fed into it.
#
#
# The model explored here uses a different formula for mobility which separates all the values even those judged too colinear by the authors of the original study.
#
#     ~ -1 + residential + transit + grocery + parks + retail + workplace

# %%
# %load_ext autoreload

# %%
# %autoreload 2
# %matplotlib notebook

# %%
import os
from pathlib import Path
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ## Method
#
# This analysis is done by comparing the reported, modelled and forecasted deaths for 4 countries: France, Spain, Italy and the UK. These countries were picked as they present similar epidemics as judged by number of deaths. They do however present different lags with Italy's being the most advanced, followed by Spain and France, and finally followed by the UK.
#
# Simulations provided with increasing days of reports are plotted on the same graph. "Convergence" is assessed visually by finding the point at which modelled and forecasted mean lines stop changing as more data is added.
#
# Below are the plotting functions. In each plot data is grouped by code version and the fitting conditions. For France two fitting conditions exist:
#
# - Fitting with influence from Europe and French regions;
# - Fitting with influence from French regions only;
#
# The effect of this difference has not been evaluated yet.

# %%
from model_analysis import *

# %%
run_manifest = read_manifest('run-manifest.csv')
analysis_set = get_analysis_set(run_manifest)

# %% [markdown]
# ## Group data in comparable runs

# %%
def group_by_version_and_country_num(df, x):
    regions = "No region"
    if df.loc[x, "number of zones"]>14:
        regions = "With regions"
    countries = "France only"
    if df.loc[x, "number of countries"]>1:
        countries = "Europe"
    JOBID = df.loc[x, "folder"][-7:-1]
    try:
        is_original_pooling = (
            '~ -1 + residential + transit + grocery + parks + retail + workplace'
            == df.loc[x, "model"].data["arguments"]["formula_pooling"].strip()
        ) and (
            '~ -1 + residential + transit + grocery + parks + retail + workplace'
            == df.loc[x, "model"].data["arguments"]["formula_partialpooling"].strip()
        )
    except:
        is_original_pooling = False
    return (df.loc[x, "version"], countries, regions, JOBID, is_original_pooling)

groups = analysis_set.groupby(lambda x : group_by_version_and_country_num(analysis_set, x))

# %%
func = lambda x: x[2]=="With regions" and x[0].strip()=="v5" and x[4]
for i, group in enumerate(groups):
        print(f"Group {i + 1} of {len(groups)}: {group[0]}")
# Out:
# Group 1 of 37: ('v2', 'Europe', 'No region', '-93205', False)
# Group 2 of 37: ('v2', 'Europe', 'With regions', '-56805', False)
# Group 3 of 37: ('v2', 'Europe', 'With regions', '-66081', False)
# Group 4 of 37: ('v2', 'Europe', 'With regions', '-84432', False)
# Group 5 of 37: ('v2', 'Europe', 'With regions', '363845', False)
# Group 6 of 37: ('v2', 'France only', 'With regions', '136654', False)
# Group 7 of 37: ('v2', 'France only', 'With regions', '363690', False)
# Group 8 of 37: ('v2', 'France only', 'With regions', '363843', False)
# Group 9 of 37: ('v2', 'France only', 'With regions', '364102', False)
# Group 10 of 37: ('v3', 'Europe', 'With regions', '366561', False)
# Group 11 of 37: ('v3', 'Europe', 'With regions', '367777', False)
# Group 12 of 37: ('v3', 'Europe', 'With regions', '367970', False)
# Group 13 of 37: ('v3', 'Europe', 'With regions', '376114', False)
# Group 14 of 37: ('v3', 'France only', 'With regions', '367777', False)
# Group 15 of 37: ('v3', 'France only', 'With regions', '367778', False)
# Group 16 of 37: ('v3', 'France only', 'With regions', '367826', False)
# Group 17 of 37: ('v3', 'France only', 'With regions', '367827', False)
# Group 18 of 37: ('v3', 'France only', 'With regions', '376114', False)
# Group 19 of 37: ('v5', 'Europe', 'No region', '378980', False)
# Group 20 of 37: ('v5', 'Europe', 'No region', '379066', False)
# Group 21 of 37: ('v5', 'Europe', 'No region', '379270', False)
# Group 22 of 37: ('v5', 'Europe', 'No region', '379737', True)
# Group 23 of 37: ('v5', 'Europe', 'No region', '380006', False)
# Group 24 of 37: ('v5', 'Europe', 'With regions', '378980', False)
# Group 25 of 37: ('v5', 'Europe', 'With regions', '379066', False)
# Group 26 of 37: ('v5', 'Europe', 'With regions', '379270', False)
# Group 27 of 37: ('v5', 'Europe', 'With regions', '379737', True)
# Group 28 of 37: ('v5', 'Europe', 'With regions', '380006', False)
# Group 29 of 37: ('v5', 'France only', 'No region', '379066', False)
# Group 30 of 37: ('v5', 'France only', 'No region', '379270', False)
# Group 31 of 37: ('v5', 'France only', 'No region', '379737', True)
# Group 32 of 37: ('v5', 'France only', 'No region', '380006', False)
# Group 33 of 37: ('v5', 'France only', 'With regions', '378980', False)
# Group 34 of 37: ('v5', 'France only', 'With regions', '379066', False)
# Group 35 of 37: ('v5', 'France only', 'With regions', '379270', False)
# Group 36 of 37: ('v5', 'France only', 'With regions', '379737', True)
# Group 37 of 37: ('v5', 'France only', 'With regions', '380006', False)

# %%
prop_cycle = icl_plot_core.cycler(
    linestyle=[ '-', '--'],
    marker=[' ', 'v'],
    markevery=[ 1, 4]
)
icl_plot_core.default_color_map = plt.get_cmap("viridis")

# %% [markdown]
# ## Analysis of convergence on France
#
# The next few plots display data for France as a whole modelled from a range of different dates.

# %%
func = lambda x: x[2]=="With regions" and x[0].strip()=="v5" and x[4]
plot_groups(groups, "France-hopitaux", prop_cycle, 
            cond_group=func, min_date='2020-02-10', max_date='2020-07-01')
# Out:
# Plotting group 26 of 33: ('v5', 'Europe', 'With regions', '379737', True)
# Plotting group 33 of 33: ('v5', 'France only', 'With regions', '379737', True)
# Plotting group 26 of 33: ('v5', 'Europe', 'With regions', '379737', True)
# Plotting group 33 of 33: ('v5', 'France only', 'With regions', '379737', True)

# %% [markdown]
# ## Case study of European countries

# %%
func = lambda x: x[1]=="Europe" and x[0].strip()=="v5" and x[2]!="With regions" and x[4]

# %% [markdown]
# ### Spain

# %%
plot_groups(groups, "Spain", prop_cycle, 
            cond_group=func, min_date='2020-02-10', max_date='2020-07-01')
# Out:
# Plotting group 22 of 33: ('v5', 'Europe', 'No region', '379737', True)

# %% [markdown]
# ### Italy

# %%
plot_groups(groups, "Italy", prop_cycle, 
            cond_group=func, min_date='2020-02-10', max_date='2020-07-01')
# Out:
# Plotting group 22 of 33: ('v5', 'Europe', 'No region', '379737', True)

# %% [markdown]
# ### United_Kingdom

# %%
plot_groups(groups, "United_Kingdom", prop_cycle, 
            cond_group=func, min_date='2020-02-10', max_date='2020-07-01')
# Out:
# Plotting group 22 of 33: ('v5', 'Europe', 'No region', '379737', True)

# %% [markdown]
# ### Germany

# %%
plot_groups(groups, "Germany", prop_cycle, 
            cond_group=func, min_date='2020-02-10', max_date='2020-07-01')
# Out:
# Plotting group 22 of 33: ('v5', 'Europe', 'No region', '379737', True)

# %% [markdown]
# ### Netherlands

# %%
plot_groups(groups, "Netherlands", prop_cycle, 
            cond_group=func, min_date='2020-02-10', max_date='2020-07-01')
# Out:
# Plotting group 22 of 33: ('v5', 'Europe', 'No region', '379737', True)

# %% [markdown]
# ### Portugal

# %%
plot_groups(groups, "Portugal", prop_cycle, 
            cond_group=func, min_date='2020-02-10', max_date='2020-07-01')
# Out:
# Plotting group 22 of 33: ('v5', 'Europe', 'No region', '379737', True)

# %% [markdown]
# ### Denmark

# %%
plot_groups(groups, "Denmark", prop_cycle, 
            cond_group=func, min_date='2020-02-10', max_date='2020-07-01')
# Out:
# Plotting group 22 of 33: ('v5', 'Europe', 'No region', '379737', True)

# %% [markdown]
# ## Conclusions
#
# This model doesn't work. This suggests that mobility is not a sufficient predictor of $R_t$ and additional factors are needed.

# %% [markdown]
# ### Note on convergence

# %% [markdown]
# ### Future works

# %% [markdown]
# ## Acknowledgements / Thanks
#
# - The MRC at Imperial for open sourcing the model and their support
# - [Nathan Desdouits](https://github.com/nathan-tc) for his advice on cleaning up the colours of the plots.
